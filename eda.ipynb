# %%
import gzip
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with gzip.open('compensation_cpi.csv.gz', 'rb') as f:
    df = pd.read_csv(f)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1466589 entries, 0 to 1466588
# Data columns (total 15 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   year                1466589 non-null  int64
#  1   department          1466587 non-null  object
#  2   job_title           1466043 non-null  object
#  3   base_salary         1465890 non-null  float64
#  4   overtime            1433207 non-null  float64
#  5   irregular_cash      1466155 non-null  float64
#  6   total_cash          1466589 non-null  float64
#  7   retirement          1466589 non-null  float64
#  8   health              1447602 non-null  float64
#  9   other_benefits      830557 non-null   float64
#  10  total_benefits      1466589 non-null  float64
#  11  total_compensation  1466589 non-null  float64
#  12  city_id             1466589 non-null  int64
#  13  annual_average_cpi  1466589 non-null  float64
#  14  inflation_rate      1466589 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 167.8+ MB

# %%
df[df['department'].isna()]

df['department'] = df['department'].fillna('Police')

num_unique_strings = df['department'].nunique()
num_unique_strings

#df.to_csv('df1.csv', index=False)

def replace_text(text):
    if pd.isna(text) or text is None:
        return text
    elif target_word.lower() in text.lower():
        return new_word
    else:
        return text

# use the apply method to apply the replace_text function to the text_column

target_word= "Police"
new_word= "Police"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Sheriff"
new_word= "Police"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Vcet"
new_word= "Police"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Fire"
new_word= "Emergency Manangement"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Emergency"
new_word= "Emergency Manangement"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "PW"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Public"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Water"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "DOT"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "transport"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Plan"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Building"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "District"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "PRNS"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Recre"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "zoo"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Parks"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Arena"
new_word= "Public works and Planning"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "City"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Convention"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Neighbor"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Election"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Council"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "CII"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Clerk"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Registrar"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Housing"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Mayor"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "rda"
new_word= "City Management and Council"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "ESD"
new_word= "Employment"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Employee"
new_word= "Employment"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Airport"
new_word= "Airport"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Airside"
new_word= "Airport"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Econ"
new_word= "Economic Development"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Finance"
new_word= "Finance"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "treasurer"
new_word= "Finance"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Auditor"
new_word= "Finance"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Assessor"
new_word= "Finance"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Controller"
new_word= "Finance"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Tax"
new_word= "Finance"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Board"
new_word= "Law and regulation"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Attorney"
new_word= "Law and regulation"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Court"
new_word= "Law and regulation"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Ethics"
new_word= "Law and regulation"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "probation"
new_word= "Law and regulation"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "regulation"
new_word= "Law and regulation"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Prt"
new_word= "Port"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Harbor"
new_word= "Port"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Human"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Retire"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Child"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Service"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Personnel"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Aging"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Women"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Pension"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Disability"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Families"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "youth"
new_word= "Human Services"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Info"
new_word= "InformationTech"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Tech"
new_word= "InformationTech"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Envi"
new_word= "Energy and Environment"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Energy"
new_word= "Energy and Environment"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Power"
new_word= "Energy and Environment"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Sciences"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Library"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Museum"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Memorial"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Monument"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Arts"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Cultural"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

target_word= "Art commission"
new_word= "Library, Arts, Science and Museum"
df['department'] = df['department'].apply(replace_text)
num_unique_strings = df['department'].nunique()
num_unique_strings

#df.to_csv('df2.csv', index=False)

n_records = len(df)

# %%
n_records
# Out:
# 1466589

# %%
df. isna(). sum()
# Out:
# year                       0
# department                 0
# job_title                546
# base_salary              699
# overtime               33382
# irregular_cash           434
# total_cash                 0
# retirement                 0
# health                 18987
# other_benefits        636032
# total_benefits             0
# total_compensation         0
# city_id                    0
# annual_average_cpi         0
# inflation_rate             0
# dtype: int64

# %%
df['job_title'] = df['job_title'].fillna('NA')
df['base_salary'] = df['total_cash']-(df['overtime']+df['irregular_cash'])
df['overtime'] = df['overtime'].fillna(0)
df['irregular_cash'] = df['irregular_cash'].fillna(0)
df['health'] = df['health'].fillna(0)
df['other_benefits'] = df['other_benefits'].fillna(0)
df. isna(). sum()
# Out:
# year                  0
# department            0
# job_title             0
# base_salary           0
# overtime              0
# irregular_cash        0
# total_cash            0
# retirement            0
# health                0
# other_benefits        0
# total_benefits        0
# total_compensation    0
# city_id               0
# annual_average_cpi    0
# inflation_rate        0
# dtype: int64

# %%
round(df[["total_compensation"]].describe(),2).T
# Out:
#                         count       mean       std       min       25%  \
# total_compensation  1466589.0  109285.96  78432.72 -74082.61  36070.06
#
#                           50%        75%        max
# total_compensation  108704.27  161137.38  2394972.0

# %%
# group by department and calculate the average salary
grouped_data = df.groupby('department')['base_salary'].mean()
grouped_data = grouped_data.sort_values(ascending=False)

# create bar plot
plt.bar(grouped_data.index, grouped_data.values)
plt.xticks(rotation=90)
plt.xlabel('Department')
plt.ylabel('Average Compensation')
plt.title('Department Average Salary Histogram')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1466589 entries, 0 to 1466588
# Data columns (total 15 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   year                1466589 non-null  int64
#  1   department          1466589 non-null  object
#  2   job_title           1466589 non-null  object
#  3   base_salary         1433207 non-null  float64
#  4   overtime            1466589 non-null  float64
#  5   irregular_cash      1466589 non-null  float64
#  6   total_cash          1466589 non-null  float64
#  7   retirement          1466589 non-null  float64
#  8   health              1466589 non-null  float64
#  9   other_benefits      1466589 non-null  float64
#  10  total_benefits      1466589 non-null  float64
#  11  total_compensation  1466589 non-null  float64
#  12  city_id             1466589 non-null  int64
#  13  annual_average_cpi  1466589 non-null  float64
#  14  inflation_rate      1466589 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 167.8+ MB

# %%
fig, ax = plt.subplots()
ax.boxplot([df.loc[df['year'] == year, 'total_compensation'] for year in df['year'].unique()], positions=df['year'].unique())
ax.set_xlabel('Year')
ax.set_ylabel('Total_compensation')
ax.set_title('Box Plot')
plt.show()

# %%
df1=df
df1.drop(['year'], axis=1, inplace=True)

# %%
corr = df.corr()
matrix = np.triu(corr) 
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(method='pearson'), 
            annot=True, linewidths=.5, 
            cmap="coolwarm", mask=matrix,
            square = True, 
            cbar_kws={'label': 'Correlation Index'}, 
            vmin=-1, vmax=1)
plt.show()

# %%
# histograms
df1.hist(grid=False, figsize=(18,12))
plt.show()
